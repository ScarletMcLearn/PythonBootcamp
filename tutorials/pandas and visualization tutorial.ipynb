# %% [markdown]
# # Curriculum
# * pandas
# * some standard plotting (won't do seaborn today, but you should check it!)
# * some cool kid techniques for data scientists
# * python drills

# %% [markdown]
# # install
# * mplleaflet
#     * pip install mplleaflet
# * geopy
#     * pip install geopy

# %% [markdown]
# # Import relevant libraries

# %%
import pandas as pd # dataframes
import seaborn as sns # visualization
import sqlite3 # simple flatfile db
from StringIO import StringIO # fake files
from IPython.display import Image
# always do when you want to generate images
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Pandas
# * A fast and efficient DataFrame object for data manipulation with integrated indexing
# * Tools for reading and writing data in different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
# * Intelligent data alignment and integrated handling of missing data
# * Flexible reshaping and pivoting of data sets
# * Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets
# * Time series-functionality: date range generation and frequency conversion, moving window statistics, moving window linear regressions, date shifting and lagging.

# %% [markdown]
# ## read data

# %%
# read file (many more ways to fetch data: excel, json, db, url etc)
data = pd.read_csv('../data/ufo-complete-geocoded-time-standardized.clean.csv')
# Out:
# /gpfs01/home/ggayq/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# inspect data

# %%
# set columns
data.columns = ['observation_date','town','state','country_short','shape','rem','duration','description','registration_date','latitude', 'longitude']

# %%
# show images url: 
latitude ='https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/Latitude_%28PSF%29.png/330px-Latitude_%28PSF%29.png'
longitude='https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Longitude_%28PSF%29.png/330px-Longitude_%28PSF%29.png'

# %%
# Image latitude

# %%
# Image longitude

# %%
# look at data again: head and tail

# %%
# delete rem

# %%
# show shape of dataframe

# %%
# get some info on dataframe -> don't forget to include all

# %%
# remove all lines with NAs

# %%
# show country_short value counts

# %%
# plot the country_short occurence barplot, also with logy

# %%
# indexing using query: all in salem

# %%
# index using ix
# using integer

# using list

# using column list

# %%
# sort by town, state, observation data --> descending

# %%
# groupby apply --> town vs shapes concatinated by ;

# %%
# extract observation hour and set to int

# %%
# plot hour histogram

# %%
# ok a little seaborn with the distplot on observation_hour

# %%
# join country long
# show unique country_short values

# %%
# make country string

# %%
# read string into pandas via StringIO

# %%
# merge countries

# %%
# join data --> set indices

# %%
# write into database
## open the connection

## save to db (table, conn, index = False, if_exists )

# %%
# read from db

# %% [markdown]
# # get some adresses

# %%
from geopy.geocoders import Nominatim

# %%
# instantiate Nominatim

# %%
# iterate over top 10 geolocations and use geolocator.reverse to get adress
# Out:
# 28.9783333 -96.6458333 North Wells Street, Edna, Jackson County, Texas, 77957, United States of America
# 21.4180556 -157.8036111 36.5950000 -82.1888889 Scotchman, 855, State Street, Bristol, Sullivan County, Tennessee, 37625, United States of America
# 41.1175000 -73.4083333 Whole Psychotherapy, 91, East Avenue, Norwalk, Fairfield County, Connecticut, 06851, United States of America
# 33.5861111 -86.2861111 Pell City Yoga Center, 1822, Cogswell Avenue, Pell City, St. Clair County, Alabama, 35125, United States of America
# 30.2947222 -82.9841667 Ameris Bank, Court Street Southeast, Live Oak, Suwannee County, Florida, 32064, United States of America
# 33.9163889 -118.3516667 West El Segundo Boulevard, Hawthorne, Los Angeles County, California, 90250, United States of America
# 35.2333333 -82.7344444 OP Taylors, West Main Street, Brevard, Transylvania County, North Carolina, 28712, United States of America
# 40.6686111 -73.5275 2701, Sunrise Highway, Bellmore, Nassau County, New York, 11710, United States of America
# 37.1536111 -83.7619444 Police/911, Town Branch Road, Manchester, Clay County, Kentucky, 40962, United States of America

# %% [markdown]
# # plot 1000 random ufo sightings

# %%
import mplleaflet

# %%
# generate random row samples

# %%
# plt.scatter longitude'] vs latitude'

# display on map
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %%
# subset the australian

# %%
# plot the australian

# %% [markdown]
# # That's it (I heard one shall never end with that's it)
